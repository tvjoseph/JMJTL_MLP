# %% [markdown]
# ### Activity 7.01 : Building DCGAN for MNIST FASHION

# %%
# Import the required library functions
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Reshape, Dense, Dropout, Flatten,Activation
from tensorflow.keras.layers import LeakyReLU,BatchNormalization
from tensorflow.keras.layers import Conv2D, UpSampling2D,Conv2DTranspose
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.optimizers import Adam
from sklearn.utils import shuffle

# %%
# Function to generate real data samples
def fullData():
    # Get the MNIST data 
    (X_train, _), (_, _) = fashion_mnist.load_data()
    # Reshaping the input data to include channel
    X = X_train[:,:,:,np.newaxis]
    # normalising the data to be between 0 and 1
    X = (X.astype('float32') - 127.5)/127.5
    
    return X

# %%
X = fullData()
X.shape
# Out:
# (60000, 28, 28, 1)

# %%
# Function to generate real data samples
def realData(batch):
    # Get the MNIST data 
    (X_train, _), (_, _) = fashion_mnist.load_data()
    # Reshaping the input data to include channel
    X = X_train[:,:,:,np.newaxis]
    # normalising the data to be between 0 and 1
    X = (X.astype('float32') - 127.5)/127.5
    # Generating a batch of data
    imageBatch = X[np.random.randint(0, X.shape[0], size=batch)]
    return imageBatch

# %%
# Generating one sample of the data
fashionData = realData(25)

# %%
# Plot the image
for j in range(5*5):
    pyplot.subplot(5,5,j+1)
    pyplot.imshow(fashionData[j,:,:,0],cmap='gray_r')

# %%
# Function to generate inputs for generator function
def fakeInputs(batch,infeats):
    # Generate random noise data with shape (batch,input features)
    x_fake = np.random.uniform(-1,1,size=[batch,infeats])
    return x_fake

# %%
# Generator model experimentation bay
'''
def genModel(infeats):
    # Defining the Generator model
    Genmodel = Sequential()
    Genmodel.add(Dense(128*7*7,input_dim=infeats))
    Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Reshape((7, 7, 128)))
    # Upsampling to 14 x 14
    Genmodel.add(UpSampling2D(size=(2, 2)))
    Genmodel.add(Conv2D(64, kernel_size=(5, 5), padding='same'))
    Genmodel.add(LeakyReLU(0.2))
    # Upsampling to 28 x 28
    Genmodel.add(UpSampling2D(size=(2, 2)))
    Genmodel.add(Conv2D(1, kernel_size=(5, 5), padding='same', activation='sigmoid'))
    return Genmodel
'''
'''
def genModel(infeats):
    # Defining the Generator model
    Genmodel = Sequential()
    Genmodel.add(Dense(128*7*7,input_dim=infeats))
    #Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Reshape((7, 7, 128)))
    # Upsample to 14 x 14
    Genmodel.add(Conv2DTranspose(256,kernel_size=(2,2),strides=(2,2),padding='same'))    
    #Genmodel.add(LeakyReLU(0.2))
    # Updample to 28 x 28
    Genmodel.add(Conv2DTranspose(256,kernel_size=(2,2),strides=(2,2),padding='same'))    
    #Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Conv2D(1, kernel_size=(2, 2), padding='same', activation='sigmoid'))
    return Genmodel
'''
'''
# Exp_3
def genModel(infeats):
    # Defining the Generator model
    Genmodel = Sequential()
    Genmodel.add(Dense(128*7*7,input_dim=infeats))
    #Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Reshape((7, 7, 128)))
    # Upsample to 14 x 14
    Genmodel.add(Conv2DTranspose(256,kernel_size=(3,3),strides=(2,2),padding='same'))    
    #Genmodel.add(LeakyReLU(0.2))
    # Updample to 28 x 28
    Genmodel.add(Conv2DTranspose(256,kernel_size=(3,3),strides=(2,2),padding='same'))    
    Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Conv2D(1, kernel_size=(3, 3), padding='same', activation='sigmoid'))
    return Genmodel
'''
# Exp_4
def genModel(infeats):
    # Defining the Generator model
    Genmodel = Sequential()
    Genmodel.add(Dense(512,input_dim=infeats))
    Genmodel.add(Activation('relu'))
    Genmodel.add(BatchNormalization())
    # second layer of FC => RElu => BN layers
    Genmodel.add(Dense(7*7*64))
    Genmodel.add(Activation('relu'))
    Genmodel.add(BatchNormalization())
    # Upsample to 14 x 14
    Genmodel.add(Reshape((7,7,64)))
    Genmodel.add(Conv2DTranspose(32,kernel_size=(5,5),strides=(2,2),padding='same'))
    Genmodel.add(Activation('relu'))
    Genmodel.add(BatchNormalization(axis = -1))
    # Updample to 28 x 28
    Genmodel.add(Conv2DTranspose(1,kernel_size=(5,5),strides=(2,2),padding='same'))
    Genmodel.add(Activation('tanh'))    
    return Genmodel

# %%
'''
# Function for the generator model
def genModel(infeats):
    # Defining the Generator model
    Genmodel = Sequential()
    Genmodel.add(Dense(128*7*7,input_dim=infeats))
    Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Reshape((7, 7, 128)))
    # Upsample to 14 x 14
    Genmodel.add(Conv2DTranspose(128,kernel_size=(4,4),strides=(2,2),padding='same'))    
    Genmodel.add(LeakyReLU(0.2))
    # Updample to 28 x 28
    Genmodel.add(Conv2DTranspose(128,kernel_size=(4,4),strides=(2,2),padding='same'))    
    Genmodel.add(LeakyReLU(0.2))
    Genmodel.add(Conv2D(1, kernel_size=(7, 7), padding='same', activation='sigmoid'))
    return Genmodel
'''

# %%
# Function to create fake samples using the generator model
def fakedataGenerator(Genmodel,batch,infeats):
    # first generate the inputs to the model
    genInputs = fakeInputs(batch,infeats)
    # use these inputs inside the generator model to generate fake distribution
    X_fake = Genmodel.predict(genInputs)   
    
    return X_fake

# %%
# Define the arguments like batch size and input feature
batch = 128
infeats = 100
Genmodel = genModel(infeats,)
Genmodel.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               51712
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_v2_3 (Ba (None, 512)               2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 3136)              1608768
# _________________________________________________________________
# activation_5 (Activation)    (None, 3136)              0
# _________________________________________________________________
# batch_normalization_v2_4 (Ba (None, 3136)              12544
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 14, 14, 32)        51232
# _________________________________________________________________
# activation_6 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_v2_5 (Ba (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         801
# _________________________________________________________________
# activation_7 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,727,233
# Trainable params: 1,719,873
# Non-trainable params: 7,360
# _________________________________________________________________

# %%
# Generating a fake sample and printing the shape
fake = fakedataGenerator(Genmodel,batch,infeats)
fake.shape
# Out:
# (128, 28, 28, 1)

# %%
# Plotting the fake sample

plt.imshow(fake[1, :, :, 0], cmap='gray_r')

# %%
'''
# Descriminator model as a function
def discModel():
    Discmodel = Sequential()
    Discmodel.add(Conv2D(64,kernel_size=(3,3),strides=(2,2),padding='same',input_shape=(28,28,1)))    
    Discmodel.add(LeakyReLU(0.2))
    Discmodel.add(Dropout(0.4))
    Discmodel.add(Conv2D(64, kernel_size=(3,3), strides=(2, 2), padding='same'))   
    Discmodel.add(LeakyReLU(0.2))
    Discmodel.add(Dropout(0.4))
    Discmodel.add(Flatten())
    Discmodel.add(Dense(1, activation='sigmoid'))
    Discmodel.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5),metrics=['accuracy'])   
    return Discmodel 
'''
# Exp 6
# Descriminator model as a function
def discModel():
    Discmodel = Sequential()
    Discmodel.add(Conv2D(32,kernel_size=(5,5),strides=(2,2),padding='same',input_shape=(28,28,1)))    
    Discmodel.add(LeakyReLU(0.2))
    # second layer of convolutions
    Discmodel.add(Conv2D(64, kernel_size=(5,5), strides=(2, 2), padding='same'))   
    Discmodel.add(LeakyReLU(0.2))
    # Fully connected layers
    Discmodel.add(Flatten())
    Discmodel.add(Dense(512))
    Discmodel.add(LeakyReLU(0.2))
    Discmodel.add(Dense(1, activation='sigmoid'))
    Discmodel.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5,decay = 0.0002/1000),metrics=['accuracy'])   
    return Discmodel

# %%
'''
# Descriminator model as a function
def discModel():
    Discmodel = Sequential()
    Discmodel.add(Conv2D(64,kernel_size=(3,3),strides=(2,2),padding='same',input_shape=(28,28,1)))    
    Discmodel.add(LeakyReLU(0.2))
    Discmodel.add(Dropout(0.4))
    Discmodel.add(Conv2D(64, kernel_size=(3,3), strides=(2, 2), padding='same'))   
    Discmodel.add(LeakyReLU(0.2))
    Discmodel.add(Dropout(0.4))
    Discmodel.add(Flatten())
    Discmodel.add(Dense(1, activation='sigmoid'))
    Discmodel.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5),metrics=['accuracy'])   
    return Discmodel 
'''

# %%
# Print the summary of the discriminator model
Discmodel = discModel()
Discmodel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 32)        832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          51264
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,658,753
# Trainable params: 1,658,753
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we develop the GAN model

# %%
# Define the combined generator and discriminator model, for updating the generator
def ganModel(Genmodel,Discmodel):
    # First define that discriminator model cannot be trained
    Discmodel.trainable = False
    GanInput = Input(shape=(100,))
    GanOutput = Discmodel(Genmodel(GanInput))
    Ganmodel = Model(GanInput,GanOutput)
    # Compile the model for loss to optimise the Generator model
    Ganmodel.compile(loss='binary_crossentropy',optimizer = Adam(lr=0.0002, beta_1=0.5,decay=0.0002/1000))    
    return Ganmodel

# %%
'''
# Define the combined generator and discriminator model, for updating the generator
def ganModel(Genmodel,Discmodel):
    # First define that discriminator model cannot be trained
    Discmodel.trainable = False
    Ganmodel = Sequential()
    # First adding the generator model
    Ganmodel.add(Genmodel)
    # Next adding the discriminator model without training the parameters
    Ganmodel.add(Discmodel)
    # Compile the model for loss to optimise the Generator model
    Ganmodel.compile(loss='binary_crossentropy',optimizer = Adam(lr=0.0002, beta_1=0.5))    
    return Ganmodel
'''

# %%
# Initialise the gan model
gan_model = ganModel(Genmodel,Discmodel)
# Print summary of the GAN model
gan_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 28, 28, 1)         1727233
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 1)                 1658753
# =================================================================
# Total params: 3,385,986
# Trainable params: 1,719,873
# Non-trainable params: 1,666,113
# _________________________________________________________________

# %%
# Defining the number of epochs
nEpochs = 50

# %%
# Revising the training protocol for Experiment 6

for epoch in range(50):
    print('[INFO] starting epoch {} of {} ....'.format(epoch + 1, 50))
    batchesPerEpoch = int(X.shape[0] / batch)
    # looping over batches
    for i in range(0,batchesPerEpoch):        
        imageBatch = X[i*batch:(i+1)*batch]
        # Generating fake images
        x_fake = fakedataGenerator(Genmodel,batch,infeats)
        # Concatenating the real and fake data 
        XTrain = np.concatenate([imageBatch,x_fake])
        # Creating the Target variable
        # Creating the dependent variable and initializing them as '0'
        Y = np.zeros(batch * 2)
        # making the first set equivalent to batch with labels 1
        Y[:batch] = 1
        # Shuffling the data
        (X_Train,Y_Train) = shuffle(XTrain,Y)
        # Training the discriminator
        discLoss = Discmodel.train_on_batch(X_Train,Y_Train)
        # Generating the noise data to train the GAN
        x_gan = fakeInputs(batch*2,infeats)
        # Create labels of the fake examples as 1 to fool the discriminator
        y_gan = np.ones((batch*2, 1))
        # Update the generator model through the discriminator model
        ganLoss = gan_model.train_on_batch(x_gan, y_gan)
        if (i) % 50 == 0:
            # Printing the descriminator loss and accuracy
            print('Discriminator Loss:{D},GAN Loss : {G}'.format(D=discLoss,G=ganLoss))
            # Generate fake samples using the fake data generator function
            x_fake = fakedataGenerator(Genmodel,batch,infeats)
            # Saving the plots
            for j in range(5*5):
                pyplot.subplot(5,5,j+1)
                pyplot.imshow(x_fake[j,:,:,0],cmap='gray_r')
            filename = 'output/exp6_GAN_MNIST_Fashion_Training_Plot%03d.png' % (i)
            pyplot.savefig(filename)
            pyplot.close()
# Out:
# [INFO] starting epoch 1 of 50 ....
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Discriminator Loss:[0.69735074, 0.58984375],GAN Loss : 0.6066564917564392
# Discriminator Loss:[0.00074881804, 1.0],GAN Loss : 0.004460426047444344
# Discriminator Loss:[0.00018899131, 1.0],GAN Loss : 0.0016860808245837688
# Discriminator Loss:[7.283527e-05, 1.0],GAN Loss : 0.0009769267635419965
# Discriminator Loss:[0.00013183299, 1.0],GAN Loss : 0.0009327988373115659
# Discriminator Loss:[0.0004200399, 1.0],GAN Loss : 0.004136737901717424
# Discriminator Loss:[0.021878004, 0.99609375],GAN Loss : 0.04037986695766449
# Discriminator Loss:[0.44072533, 0.80859375],GAN Loss : 1.9158563613891602
# Discriminator Loss:[0.3634588, 0.8984375],GAN Loss : 0.9813430309295654
# Discriminator Loss:[0.4639885, 0.8125],GAN Loss : 0.6653614044189453
# [INFO] starting epoch 2 of 50 ....
# Discriminator Loss:[0.52393734, 0.6875],GAN Loss : 1.3166459798812866
# Discriminator Loss:[0.48317084, 0.765625],GAN Loss : 0.9339188933372498
# Discriminator Loss:[0.6783168, 0.625],GAN Loss : 0.9032794237136841
# Discriminator Loss:[0.47879082, 0.78125],GAN Loss : 1.3802599906921387
# Discriminator Loss:[0.5390154, 0.6640625],GAN Loss : 1.6614775657653809
# Discriminator Loss:[0.53786767, 0.703125],GAN Loss : 1.362804889678955
# Discriminator Loss:[0.528267, 0.734375],GAN Loss : 1.373734712600708
# Discriminator Loss:[0.49012187, 0.765625],GAN Loss : 1.1824803352355957
# Discriminator Loss:[0.5250832, 0.7734375],GAN Loss : 1.1521683931350708
# Discriminator Loss:[0.53805566, 0.79296875],GAN Loss : 0.8558604121208191
# [INFO] starting epoch 3 of 50 ....
# Discriminator Loss:[0.6026568, 0.6015625],GAN Loss : 1.331824779510498
# Discriminator Loss:[0.5398825, 0.73828125],GAN Loss : 1.1503351926803589
# Discriminator Loss:[0.59594744, 0.67578125],GAN Loss : 0.7646892070770264
# Discriminator Loss:[0.5851152, 0.73828125],GAN Loss : 0.9876985549926758
# Discriminator Loss:[0.51859415, 0.80859375],GAN Loss : 1.1454529762268066
# Discriminator Loss:[0.5977351, 0.68359375],GAN Loss : 0.9946518540382385
# Discriminator Loss:[0.5491034, 0.72265625],GAN Loss : 1.293143630027771
# Discriminator Loss:[0.5713701, 0.6796875],GAN Loss : 1.288707971572876
# Discriminator Loss:[0.57698345, 0.72265625],GAN Loss : 0.902483344078064
# Discriminator Loss:[0.58688515, 0.7109375],GAN Loss : 0.6849409937858582
# [INFO] starting epoch 4 of 50 ....
# Discriminator Loss:[0.7011876, 0.59375],GAN Loss : 0.5852527618408203
# Discriminator Loss:[0.62582934, 0.64453125],GAN Loss : 1.2498996257781982
# Discriminator Loss:[0.58092755, 0.7109375],GAN Loss : 1.2152496576309204
# Discriminator Loss:[0.6303556, 0.640625],GAN Loss : 0.7261102199554443
# Discriminator Loss:[0.58151674, 0.72265625],GAN Loss : 0.8527156114578247
# Discriminator Loss:[0.59932345, 0.7109375],GAN Loss : 0.7753090262413025
# Discriminator Loss:[0.58616674, 0.69921875],GAN Loss : 0.892992377281189
# Discriminator Loss:[0.5749808, 0.7421875],GAN Loss : 0.8359895348548889
# Discriminator Loss:[0.59387934, 0.73046875],GAN Loss : 0.9044300317764282
# Discriminator Loss:[0.59940445, 0.67578125],GAN Loss : 0.821841835975647
# [INFO] starting epoch 5 of 50 ....
# Discriminator Loss:[0.61521673, 0.65625],GAN Loss : 1.0348472595214844
# Discriminator Loss:[0.61665463, 0.66796875],GAN Loss : 0.8942646980285645
# Discriminator Loss:[0.6140993, 0.6484375],GAN Loss : 1.3098301887512207
# Discriminator Loss:[0.60596925, 0.6953125],GAN Loss : 0.9015437364578247
# Discriminator Loss:[0.57511187, 0.75],GAN Loss : 0.7718464136123657
# Discriminator Loss:[0.6411554, 0.58203125],GAN Loss : 1.2553421258926392
# Discriminator Loss:[0.59809387, 0.66796875],GAN Loss : 1.0291566848754883
# Discriminator Loss:[0.60404617, 0.609375],GAN Loss : 1.1616313457489014
# Discriminator Loss:[0.6316453, 0.6484375],GAN Loss : 0.7813373804092407
# Discriminator Loss:[0.6190405, 0.62890625],GAN Loss : 0.6826886534690857
# [INFO] starting epoch 6 of 50 ....
# Discriminator Loss:[0.6374728, 0.65234375],GAN Loss : 0.7661268711090088
# Discriminator Loss:[0.63546205, 0.62890625],GAN Loss : 0.9885333776473999
# Discriminator Loss:[0.60693955, 0.6796875],GAN Loss : 0.883014440536499
# Discriminator Loss:[0.6329688, 0.65234375],GAN Loss : 0.8101829290390015
# Discriminator Loss:[0.6129615, 0.67578125],GAN Loss : 0.8504492044448853
# Discriminator Loss:[0.6260057, 0.60546875],GAN Loss : 0.6368693113327026
# Discriminator Loss:[0.6319751, 0.62890625],GAN Loss : 0.798248291015625
# Discriminator Loss:[0.6086365, 0.6484375],GAN Loss : 0.8355296850204468
# Discriminator Loss:[0.63901436, 0.64453125],GAN Loss : 0.6730025410652161
# Discriminator Loss:[0.6296747, 0.6328125],GAN Loss : 0.7132138609886169
# [INFO] starting epoch 7 of 50 ....
# Discriminator Loss:[0.65628064, 0.6171875],GAN Loss : 0.6790646910667419
# Discriminator Loss:[0.638638, 0.609375],GAN Loss : 0.8887920379638672
# Discriminator Loss:[0.620687, 0.6640625],GAN Loss : 1.0093190670013428
# Discriminator Loss:[0.63343513, 0.6640625],GAN Loss : 0.8679818511009216
# Discriminator Loss:[0.63064706, 0.640625],GAN Loss : 0.666278600692749
# Discriminator Loss:[0.612239, 0.67578125],GAN Loss : 0.9943516850471497
# Discriminator Loss:[0.64051795, 0.6171875],GAN Loss : 0.6939118504524231
# Discriminator Loss:[0.5951142, 0.68359375],GAN Loss : 0.9748400449752808
# Discriminator Loss:[0.61941046, 0.6796875],GAN Loss : 0.7574242949485779
# Discriminator Loss:[0.63542813, 0.640625],GAN Loss : 0.7683653235435486
# [INFO] starting epoch 8 of 50 ....
# Discriminator Loss:[0.63367337, 0.62109375],GAN Loss : 0.8336232900619507
# Discriminator Loss:[0.65999424, 0.59375],GAN Loss : 1.0432417392730713
# Discriminator Loss:[0.6575676, 0.61328125],GAN Loss : 0.8641535043716431
# Discriminator Loss:[0.6501284, 0.62109375],GAN Loss : 0.9047014117240906
# Discriminator Loss:[0.6126177, 0.66015625],GAN Loss : 0.8451480269432068
# Discriminator Loss:[0.625831, 0.64453125],GAN Loss : 0.9423785209655762
# Discriminator Loss:[0.66630334, 0.58203125],GAN Loss : 0.6849029064178467
# Discriminator Loss:[0.6179688, 0.6640625],GAN Loss : 1.0051711797714233
# Discriminator Loss:[0.6510999, 0.62890625],GAN Loss : 0.7725229263305664
# Discriminator Loss:[0.644628, 0.63671875],GAN Loss : 0.8027498126029968
# [INFO] starting epoch 9 of 50 ....
# Discriminator Loss:[0.63928246, 0.62890625],GAN Loss : 0.9730142951011658
# Discriminator Loss:[0.67492825, 0.54296875],GAN Loss : 1.122441053390503
# Discriminator Loss:[0.6309613, 0.640625],GAN Loss : 0.8066480159759521
# Discriminator Loss:[0.6410525, 0.625],GAN Loss : 0.7765762209892273
# Discriminator Loss:[0.5979555, 0.72265625],GAN Loss : 0.8805334568023682
# Discriminator Loss:[0.6480534, 0.62890625],GAN Loss : 0.6021746397018433
# Discriminator Loss:[0.6346233, 0.625],GAN Loss : 1.0680274963378906
# Discriminator Loss:[0.60556424, 0.67578125],GAN Loss : 0.9322079420089722
# Discriminator Loss:[0.6500418, 0.63671875],GAN Loss : 0.8027232885360718
# Discriminator Loss:[0.63749385, 0.625],GAN Loss : 0.7901163101196289
# [INFO] starting epoch 10 of 50 ....
# Discriminator Loss:[0.6499057, 0.5859375],GAN Loss : 0.8123103380203247
# Discriminator Loss:[0.6405184, 0.609375],GAN Loss : 0.9051012992858887
# Discriminator Loss:[0.62407434, 0.66796875],GAN Loss : 0.7168354392051697
# Discriminator Loss:[0.65362585, 0.58203125],GAN Loss : 0.8098160028457642
# Discriminator Loss:[0.6141815, 0.69921875],GAN Loss : 0.7904558181762695
# Discriminator Loss:[0.6363635, 0.6484375],GAN Loss : 0.7778371572494507
# Discriminator Loss:[0.6319432, 0.6875],GAN Loss : 0.8654688596725464
# Discriminator Loss:[0.60552686, 0.6640625],GAN Loss : 0.9765024781227112
# Discriminator Loss:[0.65561795, 0.6171875],GAN Loss : 0.7161184549331665
# Discriminator Loss:[0.6355064, 0.65625],GAN Loss : 0.8493162393569946
# [INFO] starting epoch 11 of 50 ....
# Discriminator Loss:[0.6225074, 0.66015625],GAN Loss : 0.8216009140014648
# Discriminator Loss:[0.6305176, 0.6484375],GAN Loss : 0.7745894193649292
# Discriminator Loss:[0.6213864, 0.66796875],GAN Loss : 0.7112895250320435
# Discriminator Loss:[0.6536789, 0.609375],GAN Loss : 0.880112886428833
# Discriminator Loss:[0.61778843, 0.671875],GAN Loss : 0.9336487650871277
# Discriminator Loss:[0.6458142, 0.640625],GAN Loss : 1.0743062496185303
# Discriminator Loss:[0.6470082, 0.625],GAN Loss : 0.6825074553489685
# Discriminator Loss:[0.615091, 0.67578125],GAN Loss : 1.0511142015457153
# Discriminator Loss:[0.66205394, 0.56640625],GAN Loss : 0.8817444443702698
# Discriminator Loss:[0.6485802, 0.62109375],GAN Loss : 0.7781307101249695
# [INFO] starting epoch 12 of 50 ....
# Discriminator Loss:[0.6198871, 0.6640625],GAN Loss : 0.708499550819397
# Discriminator Loss:[0.6669262, 0.60546875],GAN Loss : 0.7607544660568237
# Discriminator Loss:[0.66808414, 0.58984375],GAN Loss : 0.8909139037132263
# Discriminator Loss:[0.6354294, 0.65234375],GAN Loss : 0.8131431937217712
# Discriminator Loss:[0.60066646, 0.6953125],GAN Loss : 0.9096401929855347
# Discriminator Loss:[0.60240823, 0.70703125],GAN Loss : 0.7281697988510132
# Discriminator Loss:[0.62915635, 0.6796875],GAN Loss : 0.862808108329773
# Discriminator Loss:[0.6409896, 0.63671875],GAN Loss : 0.8657966256141663
# Discriminator Loss:[0.6581098, 0.6015625],GAN Loss : 0.8847755193710327
# Discriminator Loss:[0.6425276, 0.62109375],GAN Loss : 0.7790424823760986
# [INFO] starting epoch 13 of 50 ....
# Discriminator Loss:[0.6360979, 0.65234375],GAN Loss : 0.6663987636566162
# Discriminator Loss:[0.6490608, 0.58984375],GAN Loss : 0.9038715362548828
# Discriminator Loss:[0.6422399, 0.59765625],GAN Loss : 1.088623285293579
# Discriminator Loss:[0.6601685, 0.6015625],GAN Loss : 0.7729780673980713
# Discriminator Loss:[0.65486467, 0.609375],GAN Loss : 0.9891711473464966
# Discriminator Loss:[0.632519, 0.64453125],GAN Loss : 0.9075771570205688
# Discriminator Loss:[0.6199588, 0.66796875],GAN Loss : 0.7597638368606567
# Discriminator Loss:[0.62340784, 0.6171875],GAN Loss : 0.8508040904998779
# Discriminator Loss:[0.6486193, 0.625],GAN Loss : 0.8673635721206665
# Discriminator Loss:[0.67340946, 0.6015625],GAN Loss : 0.8214528560638428
# [INFO] starting epoch 14 of 50 ....
# Discriminator Loss:[0.65389115, 0.58203125],GAN Loss : 0.8035410642623901
# Discriminator Loss:[0.66399795, 0.5625],GAN Loss : 0.8227794766426086
# Discriminator Loss:[0.6451756, 0.578125],GAN Loss : 1.2160136699676514
# Discriminator Loss:[0.6358844, 0.67578125],GAN Loss : 0.8562363386154175
# Discriminator Loss:[0.61592555, 0.65234375],GAN Loss : 0.9365733861923218
# Discriminator Loss:[0.6060251, 0.66015625],GAN Loss : 0.8626734018325806
# Discriminator Loss:[0.6537691, 0.61328125],GAN Loss : 0.8158473372459412
# Discriminator Loss:[0.62527734, 0.6328125],GAN Loss : 0.9817630052566528
# Discriminator Loss:[0.6344081, 0.64453125],GAN Loss : 0.8151121139526367
# Discriminator Loss:[0.65091825, 0.609375],GAN Loss : 0.7912944555282593
# [INFO] starting epoch 15 of 50 ....
# Discriminator Loss:[0.6818632, 0.55859375],GAN Loss : 0.8241069316864014
# Discriminator Loss:[0.63711464, 0.61328125],GAN Loss : 0.9391215443611145
# Discriminator Loss:[0.6192339, 0.66015625],GAN Loss : 0.893696665763855
# Discriminator Loss:[0.6348048, 0.6640625],GAN Loss : 0.9172849059104919
# Discriminator Loss:[0.5960536, 0.6953125],GAN Loss : 0.8590173125267029
# Discriminator Loss:[0.6373519, 0.63671875],GAN Loss : 1.0027825832366943
# Discriminator Loss:[0.6552445, 0.58984375],GAN Loss : 0.7215371131896973
# Discriminator Loss:[0.60458153, 0.6484375],GAN Loss : 0.9870100021362305
# Discriminator Loss:[0.6312275, 0.6328125],GAN Loss : 0.8148514628410339
# Discriminator Loss:[0.63458204, 0.66015625],GAN Loss : 0.760184645652771
# [INFO] starting epoch 16 of 50 ....
# Discriminator Loss:[0.5928974, 0.70703125],GAN Loss : 0.8166400790214539
# Discriminator Loss:[0.63433903, 0.64453125],GAN Loss : 0.9491144418716431
# Discriminator Loss:[0.6367235, 0.66796875],GAN Loss : 0.9041687846183777
# Discriminator Loss:[0.6568887, 0.56640625],GAN Loss : 0.8282251358032227
# Discriminator Loss:[0.6010185, 0.66796875],GAN Loss : 0.9597834944725037
# Discriminator Loss:[0.62639666, 0.6015625],GAN Loss : 1.0590150356292725
# Discriminator Loss:[0.6645194, 0.609375],GAN Loss : 0.6361375451087952
# Discriminator Loss:[0.59935105, 0.6875],GAN Loss : 0.759194552898407
# Discriminator Loss:[0.6452696, 0.65625],GAN Loss : 0.6886487603187561
# Discriminator Loss:[0.6235561, 0.640625],GAN Loss : 0.8425099849700928
# [INFO] starting epoch 17 of 50 ....
# Discriminator Loss:[0.621149, 0.66796875],GAN Loss : 0.7331808805465698
# Discriminator Loss:[0.62559414, 0.62890625],GAN Loss : 0.7767237424850464
# Discriminator Loss:[0.6280831, 0.64453125],GAN Loss : 0.8967953324317932
# Discriminator Loss:[0.6265314, 0.67578125],GAN Loss : 0.8902163505554199
# Discriminator Loss:[0.6105683, 0.66796875],GAN Loss : 0.9590973258018494
# Discriminator Loss:[0.63189256, 0.6484375],GAN Loss : 1.082706093788147
# Discriminator Loss:[0.6237036, 0.63671875],GAN Loss : 0.8002235293388367
# Discriminator Loss:[0.58562684, 0.73828125],GAN Loss : 1.020695686340332
# Discriminator Loss:[0.66152996, 0.63671875],GAN Loss : 0.7989016175270081
# Discriminator Loss:[0.63663363, 0.64453125],GAN Loss : 0.8815174698829651
# [INFO] starting epoch 18 of 50 ....
# Discriminator Loss:[0.63764375, 0.6484375],GAN Loss : 0.7848437428474426
# Discriminator Loss:[0.6245466, 0.625],GAN Loss : 0.9374811053276062
# Discriminator Loss:[0.6235826, 0.6484375],GAN Loss : 0.8411502838134766
# Discriminator Loss:[0.633779, 0.62890625],GAN Loss : 0.7825360894203186
# Discriminator Loss:[0.5981709, 0.69921875],GAN Loss : 0.860036313533783
# Discriminator Loss:[0.62683785, 0.625],GAN Loss : 1.023439884185791
# Discriminator Loss:[0.6011218, 0.69921875],GAN Loss : 0.7335832118988037
# Discriminator Loss:[0.60092914, 0.68359375],GAN Loss : 0.9725710153579712
# Discriminator Loss:[0.6509162, 0.6171875],GAN Loss : 0.8455303907394409
# Discriminator Loss:[0.62769264, 0.65625],GAN Loss : 0.7938264608383179
# [INFO] starting epoch 19 of 50 ....
# Discriminator Loss:[0.64486265, 0.640625],GAN Loss : 0.8990421295166016
# Discriminator Loss:[0.66897917, 0.57421875],GAN Loss : 1.012434959411621
# Discriminator Loss:[0.5897726, 0.7109375],GAN Loss : 0.7440692186355591
# Discriminator Loss:[0.64497006, 0.62109375],GAN Loss : 0.8747503757476807
# Discriminator Loss:[0.6127709, 0.66015625],GAN Loss : 0.8375077247619629
# Discriminator Loss:[0.65195996, 0.6015625],GAN Loss : 1.0156699419021606
# Discriminator Loss:[0.62354434, 0.6484375],GAN Loss : 0.9103401899337769
# Discriminator Loss:[0.6072196, 0.6796875],GAN Loss : 0.9030571579933167
# Discriminator Loss:[0.6637124, 0.609375],GAN Loss : 0.9343243837356567
# Discriminator Loss:[0.63290846, 0.6484375],GAN Loss : 0.5821605920791626
# [INFO] starting epoch 20 of 50 ....
# Discriminator Loss:[0.6230965, 0.6171875],GAN Loss : 0.8728233575820923
# Discriminator Loss:[0.65506005, 0.59375],GAN Loss : 0.870879054069519
# Discriminator Loss:[0.6324064, 0.64453125],GAN Loss : 0.995207667350769
# Discriminator Loss:[0.61634123, 0.62890625],GAN Loss : 0.8496603965759277
# Discriminator Loss:[0.631601, 0.6015625],GAN Loss : 0.99942946434021
# Discriminator Loss:[0.6232894, 0.703125],GAN Loss : 1.0594645738601685
# Discriminator Loss:[0.64184517, 0.6015625],GAN Loss : 0.8028812408447266
# Discriminator Loss:[0.61499125, 0.66015625],GAN Loss : 0.934617817401886
# Discriminator Loss:[0.64754343, 0.6015625],GAN Loss : 0.8675545454025269
# Discriminator Loss:[0.65216994, 0.609375],GAN Loss : 0.7139275670051575
# [INFO] starting epoch 21 of 50 ....
# Discriminator Loss:[0.68967885, 0.5859375],GAN Loss : 0.5783187747001648
# Discriminator Loss:[0.66697705, 0.5859375],GAN Loss : 0.8155850172042847
# Discriminator Loss:[0.5973017, 0.69140625],GAN Loss : 1.0555462837219238
# Discriminator Loss:[0.64378595, 0.6171875],GAN Loss : 0.8000549077987671
# Discriminator Loss:[0.5988749, 0.6875],GAN Loss : 0.8044902682304382
# Discriminator Loss:[0.6074074, 0.68359375],GAN Loss : 0.8617575168609619
# Discriminator Loss:[0.620566, 0.63671875],GAN Loss : 0.9129273891448975
# Discriminator Loss:[0.6007302, 0.7109375],GAN Loss : 0.9550078511238098
# Discriminator Loss:[0.63290644, 0.63671875],GAN Loss : 0.8207969665527344
# Discriminator Loss:[0.6476066, 0.62890625],GAN Loss : 0.8717222213745117
# [INFO] starting epoch 22 of 50 ....
# Discriminator Loss:[0.67796135, 0.60546875],GAN Loss : 0.6761182546615601
# Discriminator Loss:[0.6340413, 0.609375],GAN Loss : 0.7607930898666382
# Discriminator Loss:[0.6411563, 0.6328125],GAN Loss : 0.9768256545066833
# Discriminator Loss:[0.6393173, 0.640625],GAN Loss : 0.931315541267395
# Discriminator Loss:[0.6055897, 0.66015625],GAN Loss : 1.0271203517913818
# Discriminator Loss:[0.6246954, 0.6640625],GAN Loss : 0.9097030162811279
# Discriminator Loss:[0.61732715, 0.63671875],GAN Loss : 0.7291501760482788
# Discriminator Loss:[0.5945484, 0.6875],GAN Loss : 0.9623934030532837
# Discriminator Loss:[0.6440455, 0.6484375],GAN Loss : 0.9674975275993347
# Discriminator Loss:[0.64499575, 0.640625],GAN Loss : 0.9332157373428345
# [INFO] starting epoch 23 of 50 ....
# Discriminator Loss:[0.6293541, 0.625],GAN Loss : 0.9535099267959595
# Discriminator Loss:[0.64690703, 0.61328125],GAN Loss : 0.8734739422798157
# Discriminator Loss:[0.6530298, 0.62109375],GAN Loss : 0.6378512382507324
# Discriminator Loss:[0.64795136, 0.609375],GAN Loss : 0.8061662912368774
# Discriminator Loss:[0.6271162, 0.65625],GAN Loss : 0.9599342942237854
# Discriminator Loss:[0.6192802, 0.65625],GAN Loss : 1.0293138027191162
# Discriminator Loss:[0.6159421, 0.671875],GAN Loss : 0.731357753276825
# Discriminator Loss:[0.6215744, 0.64453125],GAN Loss : 1.2778723239898682
# Discriminator Loss:[0.64981246, 0.6171875],GAN Loss : 0.8581253886222839
# Discriminator Loss:[0.6498518, 0.62109375],GAN Loss : 0.8812552690505981
# [INFO] starting epoch 24 of 50 ....
# Discriminator Loss:[0.632854, 0.6171875],GAN Loss : 0.9082776308059692
# Discriminator Loss:[0.6243576, 0.6484375],GAN Loss : 0.7244570255279541
# Discriminator Loss:[0.597574, 0.67578125],GAN Loss : 0.7671235799789429
# Discriminator Loss:[0.64988077, 0.6171875],GAN Loss : 0.9973054528236389
# Discriminator Loss:[0.6021956, 0.68359375],GAN Loss : 1.0027042627334595
# Discriminator Loss:[0.6033808, 0.640625],GAN Loss : 1.0280406475067139
# Discriminator Loss:[0.65321344, 0.59765625],GAN Loss : 0.798248291015625
# Discriminator Loss:[0.6396061, 0.6171875],GAN Loss : 1.2062113285064697
# Discriminator Loss:[0.65153944, 0.6171875],GAN Loss : 0.6848001480102539
# Discriminator Loss:[0.6477661, 0.6328125],GAN Loss : 0.7279645800590515
# [INFO] starting epoch 25 of 50 ....
# Discriminator Loss:[0.62588054, 0.66796875],GAN Loss : 0.9206703901290894
# Discriminator Loss:[0.66597056, 0.61328125],GAN Loss : 0.8162994980812073
# Discriminator Loss:[0.5871025, 0.6875],GAN Loss : 0.9088114500045776
# Discriminator Loss:[0.6389174, 0.625],GAN Loss : 0.7749468088150024
# Discriminator Loss:[0.61456203, 0.6328125],GAN Loss : 0.8371713161468506
# Discriminator Loss:[0.64852214, 0.62109375],GAN Loss : 1.0962629318237305
# Discriminator Loss:[0.61317396, 0.640625],GAN Loss : 0.9742854237556458
# Discriminator Loss:[0.5861631, 0.734375],GAN Loss : 0.8547792434692383
# Discriminator Loss:[0.669733, 0.58984375],GAN Loss : 0.9918458461761475
# Discriminator Loss:[0.68682826, 0.5703125],GAN Loss : 0.5535705089569092
# [INFO] starting epoch 26 of 50 ....
# Discriminator Loss:[0.61473143, 0.6640625],GAN Loss : 0.8320074081420898
# Discriminator Loss:[0.66533697, 0.5703125],GAN Loss : 0.9540647268295288
# Discriminator Loss:[0.62395966, 0.62890625],GAN Loss : 1.187912940979004
# Discriminator Loss:[0.63161516, 0.640625],GAN Loss : 0.7189493179321289
# Discriminator Loss:[0.5995009, 0.66015625],GAN Loss : 0.9030849933624268
# Discriminator Loss:[0.6192318, 0.65234375],GAN Loss : 1.0959950685501099
# Discriminator Loss:[0.6122653, 0.67578125],GAN Loss : 0.8039810657501221
# Discriminator Loss:[0.60313594, 0.71875],GAN Loss : 0.9620624780654907
# Discriminator Loss:[0.64366496, 0.6015625],GAN Loss : 0.9989874958992004
# Discriminator Loss:[0.6165958, 0.66015625],GAN Loss : 0.9652836322784424
# [INFO] starting epoch 27 of 50 ....
# Discriminator Loss:[0.64434874, 0.640625],GAN Loss : 0.7697687745094299
# Discriminator Loss:[0.69667125, 0.546875],GAN Loss : 1.1066358089447021
# Discriminator Loss:[0.60058767, 0.640625],GAN Loss : 0.9799004793167114
# Discriminator Loss:[0.6384349, 0.59765625],GAN Loss : 0.8034332990646362
# Discriminator Loss:[0.6156055, 0.609375],GAN Loss : 1.1760668754577637
# Discriminator Loss:[0.6365576, 0.6171875],GAN Loss : 1.0381684303283691
# Discriminator Loss:[0.6604912, 0.61328125],GAN Loss : 0.7925084829330444
# Discriminator Loss:[0.5938656, 0.69921875],GAN Loss : 0.8125624656677246
# Discriminator Loss:[0.6450663, 0.6328125],GAN Loss : 0.9977356195449829
# Discriminator Loss:[0.63602036, 0.6484375],GAN Loss : 0.7518860697746277
# [INFO] starting epoch 28 of 50 ....
# Discriminator Loss:[0.6350908, 0.65234375],GAN Loss : 0.8406277894973755
# Discriminator Loss:[0.62494385, 0.6328125],GAN Loss : 0.929703950881958
# Discriminator Loss:[0.5709455, 0.70703125],GAN Loss : 0.7937353849411011
# Discriminator Loss:[0.62879777, 0.63671875],GAN Loss : 0.803499698638916
# Discriminator Loss:[0.5800693, 0.69921875],GAN Loss : 0.8696467280387878
# Discriminator Loss:[0.6508846, 0.57421875],GAN Loss : 0.9478064775466919
# Discriminator Loss:[0.61808664, 0.63671875],GAN Loss : 0.9120309352874756
# Discriminator Loss:[0.588601, 0.71875],GAN Loss : 1.099499225616455
# Discriminator Loss:[0.62601054, 0.65625],GAN Loss : 0.8344630002975464
# Discriminator Loss:[0.65048194, 0.64453125],GAN Loss : 0.8913393020629883
# [INFO] starting epoch 29 of 50 ....
# Discriminator Loss:[0.62997186, 0.6328125],GAN Loss : 0.8833832740783691
# Discriminator Loss:[0.6453179, 0.61328125],GAN Loss : 1.0217511653900146
# Discriminator Loss:[0.6222774, 0.65234375],GAN Loss : 0.801058292388916
# Discriminator Loss:[0.60805225, 0.64453125],GAN Loss : 0.848283052444458
# Discriminator Loss:[0.613873, 0.625],GAN Loss : 1.1236011981964111
# Discriminator Loss:[0.6136882, 0.6328125],GAN Loss : 0.9845998287200928
# Discriminator Loss:[0.6158178, 0.63671875],GAN Loss : 0.8675323724746704
# Discriminator Loss:[0.61612713, 0.62890625],GAN Loss : 0.9407914280891418
# Discriminator Loss:[0.6438532, 0.5859375],GAN Loss : 0.7757188081741333
# Discriminator Loss:[0.6284053, 0.64453125],GAN Loss : 0.877967119216919
# [INFO] starting epoch 30 of 50 ....
# Discriminator Loss:[0.64576215, 0.64453125],GAN Loss : 0.7241299152374268
# Discriminator Loss:[0.64158416, 0.609375],GAN Loss : 0.8653589487075806
# Discriminator Loss:[0.57875943, 0.71875],GAN Loss : 0.9199872016906738
# Discriminator Loss:[0.6340636, 0.640625],GAN Loss : 0.9142397046089172
# Discriminator Loss:[0.5803206, 0.71484375],GAN Loss : 0.9955794215202332
# Discriminator Loss:[0.6167973, 0.66015625],GAN Loss : 1.0110867023468018
# Discriminator Loss:[0.6101006, 0.6796875],GAN Loss : 0.8446630239486694
# Discriminator Loss:[0.5915349, 0.68359375],GAN Loss : 1.0861585140228271
# Discriminator Loss:[0.6351501, 0.61328125],GAN Loss : 0.7857924103736877
# Discriminator Loss:[0.64080477, 0.671875],GAN Loss : 0.9565643072128296
# [INFO] starting epoch 31 of 50 ....
# Discriminator Loss:[0.6253511, 0.6640625],GAN Loss : 0.8500196933746338
# Discriminator Loss:[0.6441988, 0.65234375],GAN Loss : 0.867526113986969
# Discriminator Loss:[0.60049105, 0.66796875],GAN Loss : 0.9951568245887756
# Discriminator Loss:[0.6039568, 0.6640625],GAN Loss : 0.8545712828636169
# Discriminator Loss:[0.609485, 0.609375],GAN Loss : 1.2595391273498535
# Discriminator Loss:[0.6226934, 0.64453125],GAN Loss : 1.1075186729431152
# Discriminator Loss:[0.61564815, 0.62890625],GAN Loss : 0.7791875004768372
# Discriminator Loss:[0.5916591, 0.67578125],GAN Loss : 0.9976351857185364
# Discriminator Loss:[0.64348316, 0.5703125],GAN Loss : 0.7326290607452393
# Discriminator Loss:[0.6289083, 0.6953125],GAN Loss : 0.9275051355361938
# [INFO] starting epoch 32 of 50 ....
# Discriminator Loss:[0.6304259, 0.6328125],GAN Loss : 0.8677858114242554
# Discriminator Loss:[0.65692586, 0.62890625],GAN Loss : 0.86940997838974
# Discriminator Loss:[0.6099235, 0.65234375],GAN Loss : 0.8941675424575806
# Discriminator Loss:[0.62576973, 0.62890625],GAN Loss : 0.8334267735481262
# Discriminator Loss:[0.57696533, 0.7109375],GAN Loss : 0.8581150770187378
# Discriminator Loss:[0.6018013, 0.65234375],GAN Loss : 1.0093755722045898
# Discriminator Loss:[0.62715673, 0.6640625],GAN Loss : 0.7896302938461304
# Discriminator Loss:[0.6110872, 0.703125],GAN Loss : 1.030857801437378
# Discriminator Loss:[0.6293273, 0.65234375],GAN Loss : 0.9228613972663879
# Discriminator Loss:[0.67293966, 0.6015625],GAN Loss : 0.7437558770179749
# [INFO] starting epoch 33 of 50 ....
# Discriminator Loss:[0.63241875, 0.64453125],GAN Loss : 0.8870056867599487
# Discriminator Loss:[0.61875474, 0.640625],GAN Loss : 0.9500920176506042
# Discriminator Loss:[0.60469055, 0.66796875],GAN Loss : 0.7244218587875366
# Discriminator Loss:[0.6169454, 0.6484375],GAN Loss : 0.8462436199188232
# Discriminator Loss:[0.57245076, 0.70703125],GAN Loss : 1.0631688833236694
# Discriminator Loss:[0.60775644, 0.65625],GAN Loss : 0.7658662796020508
# Discriminator Loss:[0.58123755, 0.71875],GAN Loss : 0.9112669229507446
# Discriminator Loss:[0.6203762, 0.60546875],GAN Loss : 1.1794614791870117
# Discriminator Loss:[0.6014862, 0.6953125],GAN Loss : 0.8102942705154419
# Discriminator Loss:[0.6155596, 0.671875],GAN Loss : 0.8547946214675903
# [INFO] starting epoch 34 of 50 ....
# Discriminator Loss:[0.6227674, 0.6328125],GAN Loss : 0.8704235553741455
# Discriminator Loss:[0.6205122, 0.65625],GAN Loss : 0.8563350439071655
# Discriminator Loss:[0.5907512, 0.65234375],GAN Loss : 1.140044927597046
# Discriminator Loss:[0.6266484, 0.6328125],GAN Loss : 0.7894057631492615
# Discriminator Loss:[0.57369924, 0.72265625],GAN Loss : 0.844685435295105
# Discriminator Loss:[0.5829718, 0.70703125],GAN Loss : 0.8057405948638916
# Discriminator Loss:[0.57120967, 0.734375],GAN Loss : 0.8747880458831787
# Discriminator Loss:[0.59743553, 0.703125],GAN Loss : 1.013422966003418
# Discriminator Loss:[0.63341314, 0.59765625],GAN Loss : 0.8655774593353271
# Discriminator Loss:[0.5978108, 0.6796875],GAN Loss : 0.7630403637886047
# [INFO] starting epoch 35 of 50 ....
# Discriminator Loss:[0.5880246, 0.67578125],GAN Loss : 0.8985118269920349
# Discriminator Loss:[0.6194134, 0.65625],GAN Loss : 0.8129221200942993
# Discriminator Loss:[0.60646915, 0.640625],GAN Loss : 1.0646512508392334
# Discriminator Loss:[0.6253784, 0.6328125],GAN Loss : 0.8269495964050293
# Discriminator Loss:[0.57660395, 0.70703125],GAN Loss : 0.9467301368713379
# Discriminator Loss:[0.5746709, 0.69140625],GAN Loss : 0.9753857254981995
# Discriminator Loss:[0.5934342, 0.6796875],GAN Loss : 0.9316879510879517
# Discriminator Loss:[0.59126186, 0.68359375],GAN Loss : 1.1532886028289795
# Discriminator Loss:[0.60802126, 0.66015625],GAN Loss : 0.8081852197647095
# Discriminator Loss:[0.627949, 0.60546875],GAN Loss : 0.8938730955123901
# [INFO] starting epoch 36 of 50 ....
# Discriminator Loss:[0.60697985, 0.68359375],GAN Loss : 0.8807211518287659
# Discriminator Loss:[0.62460065, 0.66015625],GAN Loss : 0.8890706300735474
# Discriminator Loss:[0.59608704, 0.66015625],GAN Loss : 1.1031675338745117
# Discriminator Loss:[0.591971, 0.67578125],GAN Loss : 0.80079585313797
# Discriminator Loss:[0.5964856, 0.671875],GAN Loss : 0.8487585783004761
# Discriminator Loss:[0.6159877, 0.640625],GAN Loss : 1.1738379001617432
# Discriminator Loss:[0.590204, 0.6875],GAN Loss : 0.8538045883178711
# Discriminator Loss:[0.59646803, 0.63671875],GAN Loss : 1.1226190328598022
# Discriminator Loss:[0.61835754, 0.6328125],GAN Loss : 0.9229201078414917
# Discriminator Loss:[0.65519446, 0.59765625],GAN Loss : 0.7919104695320129
# [INFO] starting epoch 37 of 50 ....
# Discriminator Loss:[0.6000602, 0.6640625],GAN Loss : 0.7981629371643066
# Discriminator Loss:[0.5874125, 0.69921875],GAN Loss : 0.8554036021232605
# Discriminator Loss:[0.56756604, 0.6796875],GAN Loss : 1.2810126543045044
# Discriminator Loss:[0.6036736, 0.69140625],GAN Loss : 0.9766000509262085
# Discriminator Loss:[0.5737339, 0.75],GAN Loss : 0.8530203104019165
# Discriminator Loss:[0.60131454, 0.6484375],GAN Loss : 1.029878854751587
# Discriminator Loss:[0.6041914, 0.703125],GAN Loss : 0.8845714330673218
# Discriminator Loss:[0.5837394, 0.7109375],GAN Loss : 0.859754204750061
# Discriminator Loss:[0.66272783, 0.58984375],GAN Loss : 0.7518459558486938
# Discriminator Loss:[0.6198391, 0.66015625],GAN Loss : 0.8145162463188171
# [INFO] starting epoch 38 of 50 ....
# Discriminator Loss:[0.6061239, 0.6640625],GAN Loss : 0.9543288946151733
# Discriminator Loss:[0.64428926, 0.640625],GAN Loss : 1.0466123819351196
# Discriminator Loss:[0.53089523, 0.71484375],GAN Loss : 0.9401282072067261
# Discriminator Loss:[0.5958861, 0.6953125],GAN Loss : 0.8403291702270508
# Discriminator Loss:[0.5955698, 0.68359375],GAN Loss : 0.9100247025489807
# Discriminator Loss:[0.5756148, 0.68359375],GAN Loss : 1.0462102890014648
# Discriminator Loss:[0.58747464, 0.6875],GAN Loss : 1.0412113666534424
# Discriminator Loss:[0.59263027, 0.6875],GAN Loss : 0.8568637371063232
# Discriminator Loss:[0.6138376, 0.6171875],GAN Loss : 0.9353963136672974
# Discriminator Loss:[0.61365986, 0.65234375],GAN Loss : 0.8789122104644775
# [INFO] starting epoch 39 of 50 ....
# Discriminator Loss:[0.60197246, 0.66796875],GAN Loss : 0.9555627107620239
# Discriminator Loss:[0.6322245, 0.625],GAN Loss : 0.8258848190307617
# Discriminator Loss:[0.6562944, 0.60546875],GAN Loss : 1.305159091949463
# Discriminator Loss:[0.62476027, 0.62109375],GAN Loss : 0.8320134282112122
# Discriminator Loss:[0.5756179, 0.71875],GAN Loss : 0.9765691161155701
# Discriminator Loss:[0.61023974, 0.66796875],GAN Loss : 0.7881544232368469
# Discriminator Loss:[0.5916156, 0.6796875],GAN Loss : 1.0332787036895752
# Discriminator Loss:[0.56595385, 0.70703125],GAN Loss : 0.9219147562980652
# Discriminator Loss:[0.59045714, 0.69140625],GAN Loss : 0.7892448902130127
# Discriminator Loss:[0.6395418, 0.58203125],GAN Loss : 0.9527270197868347
# [INFO] starting epoch 40 of 50 ....
# Discriminator Loss:[0.6002698, 0.66796875],GAN Loss : 0.7713879346847534
# Discriminator Loss:[0.6039653, 0.671875],GAN Loss : 0.9427788257598877
# Discriminator Loss:[0.5872868, 0.703125],GAN Loss : 1.0977692604064941
# Discriminator Loss:[0.58758813, 0.6875],GAN Loss : 0.6957570314407349
# Discriminator Loss:[0.56053257, 0.72265625],GAN Loss : 1.097049355506897
# Discriminator Loss:[0.56699747, 0.7265625],GAN Loss : 0.9969469308853149
# Discriminator Loss:[0.6256911, 0.6171875],GAN Loss : 0.7181541919708252
# Discriminator Loss:[0.5779411, 0.70703125],GAN Loss : 1.0326061248779297
# Discriminator Loss:[0.5973224, 0.66796875],GAN Loss : 0.8294190168380737
# Discriminator Loss:[0.62198687, 0.62890625],GAN Loss : 0.922518253326416
# [INFO] starting epoch 41 of 50 ....
# Discriminator Loss:[0.57632166, 0.734375],GAN Loss : 1.0540896654129028
# Discriminator Loss:[0.61543334, 0.66796875],GAN Loss : 0.823262095451355
# Discriminator Loss:[0.5434609, 0.7109375],GAN Loss : 0.9987616539001465
# Discriminator Loss:[0.5987641, 0.65234375],GAN Loss : 0.6793084144592285
# Discriminator Loss:[0.59187907, 0.69140625],GAN Loss : 0.9665901064872742
# Discriminator Loss:[0.56050193, 0.703125],GAN Loss : 1.0284318923950195
# Discriminator Loss:[0.5855489, 0.67578125],GAN Loss : 0.8307527303695679
# Discriminator Loss:[0.5643549, 0.71875],GAN Loss : 0.8275012969970703
# Discriminator Loss:[0.612489, 0.63671875],GAN Loss : 0.9760759472846985
# Discriminator Loss:[0.6083779, 0.671875],GAN Loss : 1.0377283096313477
# [INFO] starting epoch 42 of 50 ....
# Discriminator Loss:[0.5712576, 0.70703125],GAN Loss : 0.831973135471344
# Discriminator Loss:[0.5966949, 0.671875],GAN Loss : 0.9360074996948242
# Discriminator Loss:[0.5896023, 0.68359375],GAN Loss : 1.2386109828948975
# Discriminator Loss:[0.6061392, 0.66796875],GAN Loss : 0.8583105802536011
# Discriminator Loss:[0.5520164, 0.71875],GAN Loss : 0.8810430765151978
# Discriminator Loss:[0.58272976, 0.68359375],GAN Loss : 1.1695654392242432
# Discriminator Loss:[0.5715917, 0.703125],GAN Loss : 0.9197945594787598
# Discriminator Loss:[0.6016928, 0.67578125],GAN Loss : 0.9847697019577026
# Discriminator Loss:[0.5774187, 0.70703125],GAN Loss : 0.7966822385787964
# Discriminator Loss:[0.6308744, 0.640625],GAN Loss : 0.838612973690033
# [INFO] starting epoch 43 of 50 ....
# Discriminator Loss:[0.5796239, 0.6875],GAN Loss : 0.9610015749931335
# Discriminator Loss:[0.62601495, 0.640625],GAN Loss : 0.9334498643875122
# Discriminator Loss:[0.5988072, 0.65625],GAN Loss : 1.1837031841278076
# Discriminator Loss:[0.62827265, 0.61328125],GAN Loss : 0.9090156555175781
# Discriminator Loss:[0.56661713, 0.69140625],GAN Loss : 0.9928076267242432
# Discriminator Loss:[0.5776576, 0.68359375],GAN Loss : 1.1261011362075806
# Discriminator Loss:[0.58494496, 0.7265625],GAN Loss : 0.8965622782707214
# Discriminator Loss:[0.5535505, 0.72265625],GAN Loss : 0.8893625736236572
# Discriminator Loss:[0.5794225, 0.69140625],GAN Loss : 0.9446662664413452
# Discriminator Loss:[0.6037413, 0.640625],GAN Loss : 1.0302014350891113
# [INFO] starting epoch 44 of 50 ....
# Discriminator Loss:[0.5909866, 0.703125],GAN Loss : 0.8409079313278198
# Discriminator Loss:[0.6145366, 0.66015625],GAN Loss : 0.887967050075531
# Discriminator Loss:[0.5369937, 0.73828125],GAN Loss : 1.1623852252960205
# Discriminator Loss:[0.6071553, 0.69921875],GAN Loss : 1.070472002029419
# Discriminator Loss:[0.5781969, 0.703125],GAN Loss : 1.1169180870056152
# Discriminator Loss:[0.5462824, 0.74609375],GAN Loss : 0.8735760450363159
# Discriminator Loss:[0.5604124, 0.75390625],GAN Loss : 1.0835965871810913
# Discriminator Loss:[0.5613334, 0.71875],GAN Loss : 1.0152392387390137
# Discriminator Loss:[0.57800543, 0.68359375],GAN Loss : 0.9604389667510986
# Discriminator Loss:[0.5870483, 0.69921875],GAN Loss : 1.0131502151489258
# [INFO] starting epoch 45 of 50 ....
# Discriminator Loss:[0.572976, 0.671875],GAN Loss : 1.0412728786468506
# Discriminator Loss:[0.5744852, 0.67578125],GAN Loss : 0.7429594993591309
# Discriminator Loss:[0.6018691, 0.66015625],GAN Loss : 1.4275411367416382
# Discriminator Loss:[0.57394856, 0.69140625],GAN Loss : 0.8654352426528931
# Discriminator Loss:[0.5337037, 0.7578125],GAN Loss : 1.1438803672790527
# Discriminator Loss:[0.5629724, 0.69140625],GAN Loss : 1.1134560108184814
# Discriminator Loss:[0.6095766, 0.69140625],GAN Loss : 0.9145978689193726
# Discriminator Loss:[0.5567704, 0.70703125],GAN Loss : 0.9319109916687012
# Discriminator Loss:[0.59346265, 0.67578125],GAN Loss : 0.8067129850387573
# Discriminator Loss:[0.6254517, 0.65625],GAN Loss : 0.9071458578109741
# [INFO] starting epoch 46 of 50 ....
# Discriminator Loss:[0.56668425, 0.6953125],GAN Loss : 0.9132808446884155
# Discriminator Loss:[0.60817224, 0.671875],GAN Loss : 0.8088722229003906
# Discriminator Loss:[0.58186084, 0.68359375],GAN Loss : 1.3229727745056152
# Discriminator Loss:[0.59412146, 0.640625],GAN Loss : 0.9369776844978333
# Discriminator Loss:[0.55020946, 0.7109375],GAN Loss : 1.0001544952392578
# Discriminator Loss:[0.5412828, 0.73828125],GAN Loss : 1.1097352504730225
# Discriminator Loss:[0.56012744, 0.68359375],GAN Loss : 0.9642778635025024
# Discriminator Loss:[0.5446905, 0.73828125],GAN Loss : 1.0442144870758057
# Discriminator Loss:[0.58635205, 0.69140625],GAN Loss : 0.8810598850250244
# Discriminator Loss:[0.61118716, 0.66796875],GAN Loss : 0.9306443333625793
# [INFO] starting epoch 47 of 50 ....
# Discriminator Loss:[0.5764787, 0.7265625],GAN Loss : 0.9752787351608276
# Discriminator Loss:[0.60520864, 0.625],GAN Loss : 0.9928618669509888
# Discriminator Loss:[0.5465804, 0.71484375],GAN Loss : 1.1990145444869995
# Discriminator Loss:[0.58128846, 0.671875],GAN Loss : 0.9876452088356018
# Discriminator Loss:[0.5935712, 0.6796875],GAN Loss : 0.9615867137908936
# Discriminator Loss:[0.5487441, 0.73046875],GAN Loss : 1.0458619594573975
# Discriminator Loss:[0.5748141, 0.69140625],GAN Loss : 1.088226079940796
# Discriminator Loss:[0.6163148, 0.6796875],GAN Loss : 1.2818259000778198
# Discriminator Loss:[0.590304, 0.71875],GAN Loss : 0.8393715620040894
# Discriminator Loss:[0.59016955, 0.67578125],GAN Loss : 0.8152800798416138
# [INFO] starting epoch 48 of 50 ....
# Discriminator Loss:[0.5535444, 0.70703125],GAN Loss : 0.9621182084083557
# Discriminator Loss:[0.5731851, 0.65234375],GAN Loss : 0.8862146139144897
# Discriminator Loss:[0.6190996, 0.640625],GAN Loss : 1.3949029445648193
# Discriminator Loss:[0.5613292, 0.734375],GAN Loss : 0.9844461679458618
# Discriminator Loss:[0.564312, 0.70703125],GAN Loss : 1.001568078994751
# Discriminator Loss:[0.59928864, 0.66015625],GAN Loss : 1.330878496170044
# Discriminator Loss:[0.5524882, 0.75],GAN Loss : 0.834904670715332
# Discriminator Loss:[0.5530139, 0.7421875],GAN Loss : 1.1348915100097656
# Discriminator Loss:[0.5873766, 0.66015625],GAN Loss : 1.024141788482666
# Discriminator Loss:[0.6092876, 0.6796875],GAN Loss : 1.1777721643447876
# [INFO] starting epoch 49 of 50 ....
# Discriminator Loss:[0.6052809, 0.65625],GAN Loss : 1.0742101669311523
# Discriminator Loss:[0.60679907, 0.7109375],GAN Loss : 0.9147955775260925
# Discriminator Loss:[0.5725224, 0.6953125],GAN Loss : 1.444390058517456
# Discriminator Loss:[0.601322, 0.6328125],GAN Loss : 1.0013319253921509
# Discriminator Loss:[0.5601857, 0.71875],GAN Loss : 0.9431047439575195
# Discriminator Loss:[0.57270104, 0.66015625],GAN Loss : 1.4255658388137817
# Discriminator Loss:[0.55883396, 0.73828125],GAN Loss : 0.9136433005332947
# Discriminator Loss:[0.5764686, 0.6953125],GAN Loss : 1.2815651893615723
# Discriminator Loss:[0.6213635, 0.6875],GAN Loss : 1.1521813869476318
# Discriminator Loss:[0.5685159, 0.69140625],GAN Loss : 0.8585646152496338
# [INFO] starting epoch 50 of 50 ....
# Discriminator Loss:[0.58302134, 0.69921875],GAN Loss : 1.0444390773773193
# Discriminator Loss:[0.6131872, 0.6484375],GAN Loss : 1.048909068107605
# Discriminator Loss:[0.59774494, 0.6875],GAN Loss : 0.991449773311615
# Discriminator Loss:[0.58075655, 0.69921875],GAN Loss : 1.0378520488739014
# Discriminator Loss:[0.5509306, 0.7265625],GAN Loss : 1.117705225944519
# Discriminator Loss:[0.5531293, 0.7109375],GAN Loss : 1.0745278596878052
# Discriminator Loss:[0.5589125, 0.71875],GAN Loss : 1.0089733600616455
# Discriminator Loss:[0.5447779, 0.7265625],GAN Loss : 1.1383585929870605
# Discriminator Loss:[0.619074, 0.66015625],GAN Loss : 0.9595550298690796
# Discriminator Loss:[0.59967405, 0.67578125],GAN Loss : 0.9261020421981812

# %%
int(X.shape[0] / batch)
# Out:
# 468

# %%
# Train the GAN network
for i in range(nEpochs):
    # Generate samples equal to the bath size from the real distribution
    x_real = realData(batch)
    # Generate fake samples using the fake data generator function
    x_fake = fakedataGenerator(Genmodel,batch,infeats)
    # Concatenating the real and fake data 
    X = np.concatenate([x_real,x_fake])
    # Creating the dependent variable and initializing them as '0'
    Y = np.zeros(batch * 2)
    # making the first set equivalent to batch with labels 1
    Y[:batch] = 1
    # train the  discriminator on the real samples
    discLoss = Discmodel.train_on_batch(X, Y)
    # Generate new fake inputs for training the GAN network
    x_gan = fakeInputs(batch*2,infeats)
    # Create labels of the fake examples as 1 to fool the discriminator
    y_gan = np.ones((batch*2, 1))
    # Update the generator model through the discriminator model
    gan_model.train_on_batch(x_gan, y_gan)
    # Print the accuracy measures on the real and fake data for every 10 epochs
    if (i) % 10 == 0:
        # Printing the descriminator loss and accuracy
        x_real_test = realData(10)
        x_fake_test = fakedataGenerator(Genmodel,10,infeats)
        # Concatenating the real and fake data 
        X_test = np.concatenate([x_real_test,x_fake_test])
        # Creating the dependent variable and initializing them as '0'
        Y = np.zeros(20 * 2)
        Y[:10] = 1
        # Predicting probabilities
        preds = Discmodel.predict_proba(X_test)
        print('Discriminator probability:{D}'.format(D=np.mean(preds)))
        # Generate fake samples using the fake data generator function
        x_fake = fakedataGenerator(Genmodel,batch,infeats)
        # Saving the plots
        for j in range(5*5):
            pyplot.subplot(5,5,j+1)
            pyplot.imshow(x_fake[j,:,:,0],cmap='gray_r')
        filename = 'output/exp4_GAN_MNIST_Fashion_Training_Plot%03d.png' % (i+500)
        pyplot.savefig(filename)
        pyplot.close()
# Out:
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Discriminator probability:0.43192386627197266
# Discriminator probability:0.311813622713089
# Discriminator probability:0.27218642830848694
# Discriminator probability:0.5348280668258667
# Discriminator probability:0.4982258379459381
# Discriminator probability:0.5277530550956726
# Discriminator probability:0.3645830452442169
# Discriminator probability:0.34450289607048035
# Discriminator probability:0.4191449284553528
# Discriminator probability:0.5115563273429871
# Discriminator probability:0.6594849228858948
# Discriminator probability:0.28783684968948364
# Discriminator probability:0.4532415270805359
# Discriminator probability:0.4734579026699066
# Discriminator probability:0.5132577419281006
# Discriminator probability:0.4986118674278259
# Discriminator probability:0.6573725938796997
# Discriminator probability:0.39295026659965515
# Discriminator probability:0.45647889375686646
# Discriminator probability:0.28022098541259766
# Discriminator probability:0.4263794422149658
# Discriminator probability:0.6237321496009827
# Discriminator probability:0.49091410636901855
# Discriminator probability:0.5419690608978271
# Discriminator probability:0.35973554849624634
# Discriminator probability:0.6898873448371887
# Discriminator probability:0.4991125464439392
# Discriminator probability:0.6854496598243713
# Discriminator probability:0.43014878034591675
# Discriminator probability:0.5086832642555237

# %%
filters = [23,34,55]

for f in filters[::-1]:
    print(f)
# Out:
# 55
# 34
# 23
